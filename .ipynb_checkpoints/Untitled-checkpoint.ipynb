# %%
import tweepy
from tweepy import OAuthHandler
import pandas as pd
from textblob import TextBlob 
import numpy as np
import re

# %%
####input your credentials here
consumer_key = '1Bg2vzM5NWPkYhfrp6lrjW0n7'
consumer_secret = 'MPxboGdEzfZqVDr8yR1XQMCRQeIRPgdBV8ZfHDQ6Jlt77vBNKp'
access_token = '1051578786075082753-WDUYvUJgINvOB04vVytTZh7RsAkEIM'
access_token_secret = 'ZGxtieZXJ0qAcncIRpOohB9ubagUsFuS3N9Xut31VCuOW'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

message,favorite_count,retweet_count,created_at,user_name=[],[],[],[],[]

searchQuery="GoTracz"

# If results from a specific ID onwards are reqd, set since_id to that ID.
# else default to no lower limit, go as far back as API allows
sinceId = None

# If results only below a specific ID are, set max_id to that ID.
# else default to no upper limit, start from the most recent tweet matching the search query.
max_id = -10000000000

tweetCount = 0
tweetsPerQry = 100
while tweetCount < 10000:
            if (max_id <= 0):
                
                if (not sinceId):
                    new_tweets = api.search(q=searchQuery, count=tweetsPerQry, tweet_mode='extended')
                else:
                    new_tweets = api.search(q=searchQuery, count=tweetsPerQry,
                                            since_id=sinceId, tweet_mode='extended')
            else:
                if (not sinceId):
                    new_tweets = api.search(q=searchQuery, count=tweetsPerQry,
                                            max_id=str(max_id - 1), tweet_mode='extended')
                else:
                    new_tweets = api.search(q=searchQuery, count=tweetsPerQry,
                                            max_id=str(max_id - 1),
                                            since_id=sinceId, tweet_mode='extended')
            if not new_tweets:
                print("No more tweets found")
                break
                
            for tweet in new_tweets:
                message.append(tweet.full_text)
                favorite_count.append(tweet.favorite_count)
                retweet_count.append(tweet.retweet_count)
                created_at.append(tweet.created_at)
                
            tweetCount += len(new_tweets)
            print("Downloaded {0} tweets".format(tweetCount))
            max_id = new_tweets[-1].id


data = pd.DataFrame(data=message, columns=['Tweets'])  

df=pd.DataFrame({'Message':message,
                'Favourite Count':favorite_count,
                'Retweet Count':retweet_count,
                'Created At':created_at})
df.to_excel("GoTracz.xlsx")
print(data)
# Out:
# Downloaded 100 tweets
# Downloaded 200 tweets
# Downloaded 300 tweets
# Downloaded 382 tweets
# No more tweets found
#                                                 Tweets
# 0    RT @wyborczawroclaw: A jeśli #debataWroclaw to...
# 1    RT @RowerowyWRO: Dwa pytania dotyczące rowerzy...
# 2    Dwa pytania dotyczące rowerzystów w latarniku ...
# 3    RT @FaktyTVP3: .@GoTracz i @RokickaJulia z @Zi...
# 4    RT @FaktyTVP3: .@GoTracz i @RokickaJulia z @Zi...
# 5    RT @FaktyTVP3: .@GoTracz i @RokickaJulia z @Zi...
# 6    RT @FaktyTVP3: .@GoTracz i @RokickaJulia z @Zi...
# 7    .@GoTracz i @RokickaJulia z @ZieloniWro o odpa...
# 8    @MarcinTorz @tomaszewskitome @GoTracz Muszę sp...
# 9    @Rz_mwj @tomaszewskitome Akurat takie sformuło...
# 10   RT @NataliaSawka: Średnia wieku kandydatów na ...
# 11   RT @m_kokoszkiewicz: @GoTracz chwali się wynik...
# 12   RT @m_kokoszkiewicz: #debataWroclaw @GoTracz o...
# 13   RT @Polityka_wSieci: #debataWrocław organizowa...
# 14   Największe zaufanie do tego że wprowadzą kompl...
# 15   RT @MazurArtur: Gdyby #wyborysamorządowe nie b...
# 16   Gdyby #wyborysamorządowe nie były podporządkow...
# 17   RT @pawel_cymbor: @tomaszewskitome @wyborczawr...
# 18   RT @Zieloni: 🚉🚌🛤️ Nasze województwa zasługują ...
# 19   RT @martalempart: @culturovo @GoTracz @Katarzy...
# 20   RT @culturovo: Po debacie prezydenckiej we Wro...
# 21   @pawel_cymbor @wyborczawroclaw @KatarzynaObara...
# 22   @tomaszewskitome @wyborczawroclaw @KatarzynaOb...
# 23   @pawel_cymbor @wyborczawroclaw @KatarzynaObara...
# 24   @tomaszewskitome @wyborczawroclaw @KatarzynaOb...
# 25   RT @Polityka_wSieci: #debataWrocław organizowa...
# 26   @Polityka_wSieci @KatarzynaObara @wyborczawroc...
# 27   RT @m_kokoszkiewicz: Zachęcam do zapoznania si...
# 28   @pawel_cymbor @wyborczawroclaw @KatarzynaObara...
# 29   RT @GoTracz: Nie chcę, by Wrocław był europejs...
# ..                                                 ...
# 352  RT @wyborczawroclaw: @GoTracz: "Parę lat temu ...
# 353  RT @Rysiekthecat: Kandyduję z listy nr 3 @Ziel...
# 354  RT @wyborczawroclaw: @GoTracz: "Parę lat temu ...
# 355  RT @alarm_smogowyDS: Dolnośląski Alarm Smogowy...
# 356  RT @wyborczawroclaw: @GoTracz: "Parę lat temu ...
# 357  @culturovo @GoTracz A w polskim mieście to jes...
# 358  @GoTracz: "Parę lat temu nikt nie mówił o smog...
# 359  @BartoszKicki @GoTracz Ale co jest aż tak „pro...
# 360  @culturovo @GoTracz To nie była krytyka. Nie d...
# 361  @BartoszKicki @GoTracz Krytyka w stylu : jak s...
# 362  @culturovo @GoTracz Problem z Zielonymi polega...
# 363  @culturovo @MazurArtur @GoTracz Ładna buzia, f...
# 364  RT @GoTracz: Jeden z moich ulubionych transpar...
# 365  RT @GoTracz: Jeden z moich ulubionych transpar...
# 366  RT @GoTracz: Jeden z moich ulubionych transpar...
# 367  @pawelpomian @Zieloni @GoTracz @ZieloniWro But...
# 368  RT @pawelpomian: Głosuj na Zielonych z @GoTrac...
# 369  2/2\n15:30 @SutrykJacek \n16:30 @GoTracz \n17:...
# 370  @pawelpomian @GoTracz @ZieloniWro Pawle, niest...
# 371  RT @pawelpomian: Głosuj na Zielonych z @GoTrac...
# 372  RT @pawelpomian: Głosuj na Zielonych z @GoTrac...
# 373  Głosuj na Zielonych z @GoTracz. Kandyduję do R...
# 374  @MurzynskiMarcin @Agnieszka_Kubit @SutrykJacek...
# 375  RT @pawelpomian: .@GoTracz jako jedyna kandyda...
# 376  @culturovo @GoTracz A mężczyzn stać ;) ? Warto...
# 377  RT @culturovo: Małgorzata Tracz z Zielonych @G...
# 378  RT @culturovo: Małgorzata Tracz z Zielonych @G...
# 379  RT @culturovo: Małgorzata Tracz @GoTracz z Zie...
# 380  Małgorzata Tracz z Zielonych @GoTracz, która b...
# 381  RT @culturovo: Małgorzata Tracz @GoTracz z Zie...
#
# [382 rows x 1 columns]

# %%
import matplotlib
import matplotlib.pyplot as plt

dates = matplotlib.dates.date2num(df['Created At'])
plt.plot_date(dates, df['Favourite Count'])

plt.show()

# %%
def clean_tweet(tweet):
    '''
    Utility function to clean the text in a tweet by removing 
    links and special characters using regex.
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

def analize_sentiment(tweet):
    '''
    Utility function to classify the polarity of a tweet
    using textblob.
    '''
    analysis = TextBlob(clean_tweet(tweet))
    analysis1=analysis.translate(to='en')
    if analysis1.sentiment.polarity > 0:
        return 1
    elif analysis1.sentiment.polarity == 0:
        return 0
    else:
        return -1

    # We create a column with the result of the analysis:
data['SA'] = np.array([ analize_sentiment(tweet) for tweet in data['Tweets'] ])

# We display the updated dataframe with the new column:
display(data.head(10))

# We construct lists with classified tweets:

pos_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] > 0]
neu_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] == 0]
neg_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] < 0]

# We print percentages:

#print("Percentage of positive tweets: {}%".format(len(pos_tweets)*100/len(data['Tweets'])))
print("Percentage of neutral tweets: {}%".format(len(neu_tweets)*100/len(data['Tweets'])))
#print("Percentage de negative tweets: {}%".format(len(neg_tweets)*100/len(data['Tweets'])))
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# C:\ProgramData\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# C:\ProgramData\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# C:\ProgramData\Anaconda3\lib\http\client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# C:\ProgramData\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     706     err = None
# --> 707     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     708         af, socktype, proto, canonname, sa = res
#
# C:\ProgramData\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-67-f8d565851b5a> in <module>()
#      21
#      22     # We create a column with the result of the analysis:
# ---> 23 data['SA'] = np.array([ analize_sentiment(tweet) for tweet in data['Tweets'] ])
#      24
#      25 # We display the updated dataframe with the new column:
#
# <ipython-input-67-f8d565851b5a> in <listcomp>(.0)
#      21
#      22     # We create a column with the result of the analysis:
# ---> 23 data['SA'] = np.array([ analize_sentiment(tweet) for tweet in data['Tweets'] ])
#      24
#      25 # We display the updated dataframe with the new column:
#
# <ipython-input-67-f8d565851b5a> in analize_sentiment(tweet)
#      12     '''
#      13     analysis = TextBlob(clean_tweet(tweet))
# ---> 14     analysis1=analysis.translate(to='en')
#      15     if analysis1.sentiment.polarity > 0:
#      16         return 1
#
# C:\ProgramData\Anaconda3\lib\site-packages\textblob\blob.py in translate(self, from_lang, to)
#     539         """
#     540         return self.__class__(self.translator.translate(self.raw,
# --> 541                               from_lang=from_lang, to_lang=to))
#     542
#     543     def detect_language(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\textblob\translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      52             tk=_calculate_tk(source),
#      53         )
# ---> 54         response = self._request(url, host=host, type_=type_, data=data)
#      55         result = json.loads(response)
#      56         if isinstance(result, list):
#
# C:\ProgramData\Anaconda3\lib\site-packages\textblob\translate.py in _request(self, url, host, type_, data)
#      90         if host or type_:
#      91             req.set_proxy(host=host, type=type_)
# ---> 92         resp = request.urlopen(req)
#      93         content = resp.read()
#      94         return content.decode('utf-8')
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in http_open(self, req)
#    1343
#    1344     def http_open(self, req):
# -> 1345         return self.do_open(http.client.HTTPConnection, req)
#    1346
#    1347     http_request = AbstractHTTPHandler.do_request_
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#    1321         except:
#
# URLError: <urlopen error [Errno 11001] getaddrinfo failed>

# %%
test=TextBlob(df['Message'][1])
print(test)
test.translate(to='en')
test.sentiment.polarity
# Out:
# RT @RowerowyWRO: Dwa pytania dotyczące rowerzystów w latarniku prezydenckim @wyborczawroclaw. Odpowiadają @SutrykJacek @RozeckaPL @Michalak…
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# C:\ProgramData\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# C:\ProgramData\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# C:\ProgramData\Anaconda3\lib\http\client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# C:\ProgramData\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     706     err = None
# --> 707     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     708         af, socktype, proto, canonname, sa = res
#
# C:\ProgramData\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-52-e38f59be82ad> in <module>()
#       1 test=TextBlob(df['Message'][1])
#       2 print(test)
# ----> 3 test.translate(to='en')
#       4 test.sentiment.polarity
#
# C:\ProgramData\Anaconda3\lib\site-packages\textblob\blob.py in translate(self, from_lang, to)
#     539         """
#     540         return self.__class__(self.translator.translate(self.raw,
# --> 541                               from_lang=from_lang, to_lang=to))
#     542
#     543     def detect_language(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\textblob\translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      52             tk=_calculate_tk(source),
#      53         )
# ---> 54         response = self._request(url, host=host, type_=type_, data=data)
#      55         result = json.loads(response)
#      56         if isinstance(result, list):
#
# C:\ProgramData\Anaconda3\lib\site-packages\textblob\translate.py in _request(self, url, host, type_, data)
#      90         if host or type_:
#      91             req.set_proxy(host=host, type=type_)
# ---> 92         resp = request.urlopen(req)
#      93         content = resp.read()
#      94         return content.decode('utf-8')
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in http_open(self, req)
#    1343
#    1344     def http_open(self, req):
# -> 1345         return self.do_open(http.client.HTTPConnection, req)
#    1346
#    1347     http_request = AbstractHTTPHandler.do_request_
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#    1321         except:
#
# URLError: <urlopen error [Errno 11001] getaddrinfo failed>
