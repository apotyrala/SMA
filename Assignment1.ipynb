# %%
import folium
import pandas as pd

# %%
twitterdata=pd.ExcelFile('export_dashboard_x_uk_x_filter_nativeretweets_geocode_55_378051_3_43597299999999_750km_2016_04_21_10_32_03.xlsx')
location1 = pd.read_excel(twitterdata, 1)

# %%
hashtags = pd.ExcelFile('export_content_x_uk_x_filter_nativeretweets_geocode_55_378051_3_43597299999999_750km_2016_04_21_11_46_43.xlsx')
top = pd.read_excel(hashtags, 6)

# %%
SF_COORDINATES = (54.7, -4.36)
map = folium.Map(location=[51.508530, -0.076132],
                        zoom_start=7,
                        tiles="CartoDB dark_matter")

# add a marker for every record in the filtered data, use a clustered view
for each in coordinates[0:2000].iterrows():

    folium.CircleMarker(
        location = [each[1]['Latitude'],each[1]['Longitude']], 
        radius=3,
        color=
        fill=True).add_to(map)
  

display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from folium import plugins

map1 = folium.Map(location=[51.508530, -0.076132],
                        zoom_start=7,
                        tiles="CartoDB dark_matter")

coordinates1=coordinates[['Latitude', 'Longitude']].values

map1.add_child(plugins.HeatMap(coordinates1, radius=15))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
